# %%
from ecd import get_inputs

event, quest = 2025, 3

# %% [markdown]
# ## Part 1

# %%
data1 = get_inputs(event=event, quest=quest)['1']

# %%
sum(set(int(d) for d in data1.split(',')))

# %% [markdown]
# ## Part 2

# %%
data2 = get_inputs(event=event, quest=quest)['2']

# %%
sum(sorted(set(int(d) for d in data2.split(',')))[:20])

# %% [markdown]
# ## Part 3

# %%
data3 = get_inputs(event=event, quest=quest)['3']

# %%
from collections import Counter

Counter(int(d) for d in data3.split(',')).most_common()
